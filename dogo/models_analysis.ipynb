# %%
import os

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.rc('font', size=16)

# %% [markdown]
# # Common Dir/Filenames

# %%
# SAC
SAC_ROLLOUT_RETURN_FILENAME = "rollout_return.csv"
SAC_EVALUATION_FILENAME = "evaluation.csv"

# Dynamics
DYNAMICS_OBS_ERROR_FILENAME = "obs_error.csv"
DYNAMICS_REW_ERROR_FILENAME = "rew_error.csv"

# MOPO
MOPO_ENVIRONMENT_FILENAME = "environment.csv"
MOPO_VALUE_SCALE_FILENAME = "value_scale.csv"

# %% [markdown]
# # SAC - D3RL001-D3RL003

# %%
D3RL001_SAC_RESULTS = "../../dogo_results/d3rlpy/models/sac/HalfCheetah-v2/2022.05.10-18:13:40/SAC_online_20220510181343"
D3RL002_SAC_RESULTS = "../../dogo_results/d3rlpy/models/sac/HalfCheetah-v2/2022.05.10-18:13:41/SAC_online_20220510181345"
D3RL003_SAC_RESULTS = "../../dogo_results/d3rlpy/models/sac/HalfCheetah-v2/2022.05.10-18:13:42/SAC_online_20220510181344"

# %%
d3rl001_sac_rollout_return = pd.read_csv(os.path.join(D3RL001_SAC_RESULTS, SAC_ROLLOUT_RETURN_FILENAME), header=None, names='index step return'.split())
d3rl002_sac_rollout_return = pd.read_csv(os.path.join(D3RL002_SAC_RESULTS, SAC_ROLLOUT_RETURN_FILENAME), header=None, names='index step return'.split())
d3rl003_sac_rollout_return = pd.read_csv(os.path.join(D3RL003_SAC_RESULTS, SAC_ROLLOUT_RETURN_FILENAME), header=None, names='index step return'.split())

# %%
d3rl001_sac_evaluation = pd.read_csv(os.path.join(D3RL001_SAC_RESULTS, SAC_EVALUATION_FILENAME), header=None, names='index step return'.split())
d3rl002_sac_evaluation = pd.read_csv(os.path.join(D3RL002_SAC_RESULTS, SAC_EVALUATION_FILENAME), header=None, names='index step return'.split())
d3rl003_sac_evaluation = pd.read_csv(os.path.join(D3RL003_SAC_RESULTS, SAC_EVALUATION_FILENAME), header=None, names='index step return'.split())

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,10))
ax.plot(d3rl001_sac_rollout_return['step'], d3rl001_sac_rollout_return['return'], label='D3RL001')
ax.plot(d3rl002_sac_rollout_return['step'], d3rl002_sac_rollout_return['return'], label='D3RL002')
ax.plot(d3rl003_sac_rollout_return['step'], d3rl003_sac_rollout_return['return'], label='D3RL003')
ax.set_xlabel('Steps')
ax.set_ylabel('Return')
ax.legend()
pass

# %% [markdown]
# # Environment Dynamics Model - D3RL004

# %%
D3RL004_DYNAMICS_RESULTS_DIR = "../../dogo_results/d3rlpy/models/dynamics/sac/HalfCheetah-v2/sac_2022.05.10-18:13:40/data_2022.05.11-11:17:04/2022.05.12-17:56:07/ProbabilisticEnsembleDynamics_20220512175607"

# %%
d3rl004_dynamics_obs_error = pd.read_csv(os.path.join(D3RL004_DYNAMICS_RESULTS_DIR, DYNAMICS_OBS_ERROR_FILENAME), header=None, names='index step mean_ep_reward'.split())
d3rl004_dynamics_rew_error = pd.read_csv(os.path.join(D3RL004_DYNAMICS_RESULTS_DIR, DYNAMICS_REW_ERROR_FILENAME), header=None, names='index step mean_ep_reward'.split())

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,10))
ax.plot(d3rl004_dynamics_obs_error['step'], d3rl004_dynamics_obs_error['mean_ep_reward'], label='D3RL004')
ax.set_xlabel('Steps')
ax.set_ylabel('Observation MSE')
ax.legend()

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,10))
ax.plot(d3rl004_dynamics_rew_error['step'], d3rl004_dynamics_rew_error['mean_ep_reward'], label='D3RL004')
ax.set_xlabel('Steps')
ax.set_ylabel('Reward MSE')
ax.legend()

# %% [markdown]
# # MOPO - D3RL005-D3RL006

# %%
D3RL005_MOPO_RESULTS_DIR = "../../dogo_results/d3rlpy/models/mopo/HalfCheetah-v2/sac_2022.05.10-18:13:40/dynamics_2022.05.12-17:56:07/data_2022.05.11-11:17:04/2022.05.14-12:36:43/MOPO_None_20220514123645"
D3RL006_MOPO_RESULTS_DIR = "../../dogo_results/d3rlpy/models/mopo/HalfCheetah-v2/sac_2022.05.10-18:13:40/dynamics_2022.05.12-17:56:07/data_2022.05.11-11:17:04/2022.05.14-13:44:51/MOPO_None_20220514134455"

# %%
d3rl004_mopo_environment = pd.read_csv(os.path.join(D3RL005_MOPO_RESULTS_DIR, MOPO_ENVIRONMENT_FILENAME), header=None, names='index step mean_ep_reward'.split())
d3rl005_mopo_environment = pd.read_csv(os.path.join(D3RL006_MOPO_RESULTS_DIR, MOPO_ENVIRONMENT_FILENAME), header=None, names='index step mean_ep_reward'.split())

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,10))
ax.plot(d3rl004_mopo_environment['step'], d3rl004_mopo_environment['mean_ep_reward'], label='D3RL005')
ax.plot(d3rl005_mopo_environment['step'], d3rl005_mopo_environment['mean_ep_reward'], label='D3RL006')

ax.set_xlabel('Steps')
ax.set_ylabel('Mean Episode Returns')
ax.legend()

# %% [markdown]
# # Environment Dynamics Model - D3RL007

# %%
D3RL007_DYNAMICS_RESULTS_DIR = "../../dogo_results/d3rlpy/models/dynamics/SAC-PAP1/HalfCheetah-v2/SAC-PAP1_2022.05.10-18:13:40/data_2022.05.19-11:30:00/2022.05.19-14:34:34/Dynamics_None_20220519143435"

# %%
d3rl007_dynamics_obs_error = pd.read_csv(os.path.join(D3RL007_DYNAMICS_RESULTS_DIR, DYNAMICS_OBS_ERROR_FILENAME), header=None, names='index step mean_ep_reward'.split())
d3rl007_dynamics_rew_error = pd.read_csv(os.path.join(D3RL007_DYNAMICS_RESULTS_DIR, DYNAMICS_REW_ERROR_FILENAME), header=None, names='index step mean_ep_reward'.split())

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,10))
ax.plot(d3rl004_dynamics_obs_error['step'], d3rl004_dynamics_obs_error['mean_ep_reward'], label='D3RL004')
ax.plot(d3rl007_dynamics_obs_error['step'], d3rl007_dynamics_obs_error['mean_ep_reward'], label='D3RL008')
ax.set_xlabel('Steps')
ax.set_ylabel('Observation MSE')
ax.legend()
pass

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,10))
ax.plot(d3rl004_dynamics_rew_error['step'], d3rl004_dynamics_rew_error['mean_ep_reward'], label='D3RL004')
ax.plot(d3rl007_dynamics_rew_error['step'], d3rl007_dynamics_rew_error['mean_ep_reward'], label='D3RL008')
ax.set_xlabel('Steps')
ax.set_ylabel('Reward MSE')
ax.legend()
pass

# %% [markdown]
# # MOPO - D3RL008

# %%
D3RL008_MOPO_RESULTS_DIR = "../../dogo_results/d3rlpy/models/mopo/HalfCheetah-v2/SAC-PAP1_2022.05.10-18:13:40/dynamics_2022.05.19-14:34:34/data_2022.05.19-11:30:00/2022.05.19-15:24:10/MOPO_None_20220519152413"

# %%
d3rl008_mopo_environment = pd.read_csv(os.path.join(D3RL008_MOPO_RESULTS_DIR, MOPO_ENVIRONMENT_FILENAME), header=None, names='index step mean_ep_reward'.split())

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,10))
ax.plot(d3rl005_mopo_environment['step'], d3rl005_mopo_environment['mean_ep_reward'], label='D3RL005')
ax.plot(d3rl008_mopo_environment['step'], d3rl008_mopo_environment['mean_ep_reward'], label='D3RL008')
ax.set_xlabel('Steps')
ax.set_ylabel('Mean Episode Returns')
ax.legend()
pass

# %% [markdown]
# # SAC - D3RL009

# %%
D3RL009_SAC_RESULTS = "../../dogo_results/d3rlpy/models/sac/HalfCheetah-v2/2022.05.20-14:24:10/SAC_None_20220520142412"

# %%
d3rl009_sac_rollout_return = pd.read_csv(os.path.join(D3RL009_SAC_RESULTS, SAC_ROLLOUT_RETURN_FILENAME), header=None, names='index step return'.split())

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,10))
ax.plot(d3rl009_sac_rollout_return['step'], d3rl009_sac_rollout_return['return'], label='D3RL009')
ax.set_xlabel('Steps')
ax.set_ylabel('Return')
ax.legend()
pass

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,10))
ax.plot(d3rl001_sac_rollout_return['step'], d3rl001_sac_rollout_return['return'], label='D3RL001')
ax.plot(d3rl002_sac_rollout_return['step'], d3rl002_sac_rollout_return['return'], label='D3RL002')
ax.plot(d3rl003_sac_rollout_return['step'], d3rl003_sac_rollout_return['return'], label='D3RL003')
ax.plot(d3rl009_sac_rollout_return['step'], d3rl009_sac_rollout_return['return'], label='D3RL009')
ax.set_xlabel('Steps')
ax.set_ylabel('Return')
ax.legend()
pass

# %%
fig, ax = plt.subplots(1, 1, figsize=(20,10))
ax.plot(d3rl001_sac_rollout_return['step'], d3rl001_sac_rollout_return['return'], label='D3RL001')
ax.plot(d3rl002_sac_rollout_return['step'], d3rl002_sac_rollout_return['return'], label='D3RL002')
ax.plot(d3rl003_sac_rollout_return['step'], d3rl003_sac_rollout_return['return'], label='D3RL003')
ax.set_xlabel('Steps')
ax.set_ylabel('Evaluation Return Average')
ax.legend()
pass

# %%
np.std([
    d3rl001_sac_rollout_return[d3rl001_sac_rollout_return['step'].isin([100000])]['return'],
    d3rl002_sac_rollout_return[d3rl001_sac_rollout_return['step'].isin([100000])]['return'],
    d3rl003_sac_rollout_return[d3rl001_sac_rollout_return['step'].isin([100000])]['return']
])
# Out:
# 266.4343744490487

# %%
d3rl001_sac_rollout_return[d3rl001_sac_rollout_return['step'].isin([20000, 40000, 60000, 80000, 100000])][['step', 'return']].round()
# Out:
#       step  return
# 19   20000   154.0
# 39   40000  2372.0
# 59   60000  3241.0
# 79   80000  3708.0
# 99  100000  4167.0

# %%
d3rl002_sac_rollout_return[d3rl002_sac_rollout_return['step'].isin([20000, 40000, 60000, 80000, 100000])][['step', 'return']].round()
# Out:
#       step  return
# 19   20000    47.0
# 39   40000  2009.0
# 59   60000  2938.0
# 79   80000  3846.0
# 99  100000  4402.0

# %%
d3rl003_sac_rollout_return[d3rl003_sac_rollout_return['step'].isin([20000, 40000, 60000, 80000, 100000])][['step', 'return']].round()
# Out:
#       step  return
# 19   20000  -188.0
# 39   40000   530.0
# 59   60000  4158.0
# 79   80000  4620.0
# 99  100000  4812.0

# %% [markdown]
# # SAC - D3RL037-D3RL039

# %%
D3RL037_SAC_RESULTS = "../../dogo_results/d3rlpy/models/sac/HalfCheetah-v2/2022.06.29-10:27:23/SAC_1443_20220629102726"
D3RL038_SAC_RESULTS = "../../dogo_results/d3rlpy/models/sac/HalfCheetah-v2/2022.06.29-10:27:22/SAC_1234_20220629102726"
D3RL039_SAC_RESULTS = "../../dogo_results/d3rlpy/models/sac/HalfCheetah-v2/2022.06.29-10:27:21/SAC_4321_20220629102726"

# %%
d3rl037_sac_rollout_return = pd.read_csv(os.path.join(D3RL037_SAC_RESULTS, SAC_ROLLOUT_RETURN_FILENAME), header=None, names='index step return'.split())
d3rl038_sac_rollout_return = pd.read_csv(os.path.join(D3RL038_SAC_RESULTS, SAC_ROLLOUT_RETURN_FILENAME), header=None, names='index step return'.split())
d3rl039_sac_rollout_return = pd.read_csv(os.path.join(D3RL039_SAC_RESULTS, SAC_ROLLOUT_RETURN_FILENAME), header=None, names='index step return'.split())

# %%
d3rl037_sac_evaluation = pd.read_csv(os.path.join(D3RL037_SAC_RESULTS, SAC_EVALUATION_FILENAME), header=None, names='index step return'.split())
d3rl038_sac_evaluation = pd.read_csv(os.path.join(D3RL038_SAC_RESULTS, SAC_EVALUATION_FILENAME), header=None, names='index step return'.split())
d3rl039_sac_evaluation = pd.read_csv(os.path.join(D3RL039_SAC_RESULTS, SAC_EVALUATION_FILENAME), header=None, names='index step return'.split())

# %%
fig, ax = plt.subplots(1, 1, figsize=(20,10))

max_steps = 100
ax.plot(d3rl037_sac_rollout_return['step'][:max_steps], d3rl037_sac_rollout_return['return'][:max_steps], label='D3RL037')
ax.plot(d3rl038_sac_rollout_return['step'][:max_steps], d3rl038_sac_rollout_return['return'][:max_steps], label='D3RL038')
ax.plot(d3rl039_sac_rollout_return['step'][:max_steps], d3rl039_sac_rollout_return['return'][:max_steps], label='D3RL039')
ax.set_xlabel('Steps')
ax.set_ylabel('Evaluation Return Average')
ax.legend()
pass

# %%
d3rl037_sac_rollout_return[d3rl037_sac_rollout_return['step'].isin([100000, 200000, 500000, 1000000, 2000000])][['step', 'return']]
# Out:
#        step       return
# 4    100000  3743.546908
# 9    200000  5050.313014
# 24   500000  7225.025764
# 49  1000000  8299.913124
# 99  2000000  9021.901699

# %%
training_eval_vals = []
for res_df in [d3rl037_sac_rollout_return, d3rl038_sac_rollout_return, d3rl039_sac_rollout_return]:
    training_eval_vals.append(res_df[res_df['step'].isin([100000, 200000, 500000, 1000000, 2000000])]['return'].values)
training_eval_vals = np.vstack(training_eval_vals)
np.round(training_eval_vals.mean(axis=0),0), np.round(training_eval_vals.std(axis=0),0)
# Out:
# (array([3789., 5172., 7298., 8691., 9710.]),
#  array([ 187.,   93.,  635., 1108., 1193.]))

# %%
fig, ax = plt.subplots(1, 1, figsize=(20,10))
ax.plot(d3rl001_sac_rollout_return['step'], d3rl001_sac_rollout_return['return'], label='D3RL001')
ax.plot(d3rl002_sac_rollout_return['step'], d3rl002_sac_rollout_return['return'], label='D3RL002')
ax.plot(d3rl003_sac_rollout_return['step'], d3rl003_sac_rollout_return['return'], label='D3RL003')
ax.plot(d3rl037_sac_rollout_return['step'], d3rl037_sac_rollout_return['return'], label='D3RL037')
ax.plot(d3rl038_sac_rollout_return['step'], d3rl038_sac_rollout_return['return'], label='D3RL038')
ax.plot(d3rl039_sac_rollout_return['step'], d3rl039_sac_rollout_return['return'], label='D3RL039')
ax.set_xlabel('Steps')
ax.set_ylabel('Return')
ax.set_xlim(0,100000)
ax.set_ylim(-500,6000)
ax.legend()
pass

# %%
training_eval_vals = []
for res_df in [d3rl001_sac_rollout_return, d3rl002_sac_rollout_return, d3rl003_sac_rollout_return]:
    training_eval_vals.append(res_df[res_df['step'].isin([20000, 40000, 60000, 80000, 100000])]['return'].values)
training_eval_vals = np.vstack(training_eval_vals)
training_eval_vals.mean(axis=0), training_eval_vals.std(axis=0)
# Out:
# (array([4.28079331e+00, 1.63692520e+03, 3.44558521e+03, 4.05780420e+03,
#         4.46022011e+03]),
#  array([142.9653304 , 796.82038718, 518.55550158, 401.38382437,
#         266.43437445]))

# %% [markdown]
# # SAC - D3RL040-D3RL042 - Hopper

# %%
D3RL040_SAC_RESULTS = "../../dogo_results/d3rlpy/models/sac/Hopper-v2/2022.08.31-14:32:55/SAC_1443_20220831143300"
D3RL041_SAC_RESULTS = "../../dogo_results/d3rlpy/models/sac/Hopper-v2/2022.08.31-14:32:54/SAC_1234_20220831143300"
D3RL042_SAC_RESULTS = "../../dogo_results/d3rlpy/models/sac/Hopper-v2/2022.08.31-14:34:23/SAC_4321_20220831143424"

# %%
d3rl040_sac_rollout_return = pd.read_csv(os.path.join(D3RL040_SAC_RESULTS, SAC_ROLLOUT_RETURN_FILENAME), header=None, names='index step return'.split())
d3rl041_sac_rollout_return = pd.read_csv(os.path.join(D3RL041_SAC_RESULTS, SAC_ROLLOUT_RETURN_FILENAME), header=None, names='index step return'.split())
d3rl042_sac_rollout_return = pd.read_csv(os.path.join(D3RL042_SAC_RESULTS, SAC_ROLLOUT_RETURN_FILENAME), header=None, names='index step return'.split())

# %%
d3rl040_sac_evaluation = pd.read_csv(os.path.join(D3RL040_SAC_RESULTS, SAC_EVALUATION_FILENAME), header=None, names='index step return'.split())
d3rl041_sac_evaluation = pd.read_csv(os.path.join(D3RL041_SAC_RESULTS, SAC_EVALUATION_FILENAME), header=None, names='index step return'.split())
d3rl042_sac_evaluation = pd.read_csv(os.path.join(D3RL042_SAC_RESULTS, SAC_EVALUATION_FILENAME), header=None, names='index step return'.split())

# %%
fig, ax = plt.subplots(1, 1, figsize=(20,10))
ax.plot(d3rl040_sac_rollout_return['step'], d3rl040_sac_rollout_return['return'], label='D3RL040')
ax.plot(d3rl041_sac_rollout_return['step'], d3rl041_sac_rollout_return['return'], label='D3RL041')
ax.plot(d3rl042_sac_rollout_return['step'], d3rl042_sac_rollout_return['return'], label='D3RL042')
ax.set_xlabel('Steps')
ax.set_ylabel('Return')
# ax.set_xlim(0,100000)
# ax.set_ylim(-500,6000)
ax.legend()
pass

# %%
d3rl041_sac_rollout_return[d3rl041_sac_rollout_return['step'].isin([100000, 200000, 400000, 600000, 800000, 1000000])][['step', 'return']]
# Out:
#        step       return
# 4    100000  2566.712342
# 9    200000  1974.324780
# 19   400000  2394.866012
# 29   600000  2157.848681
# 39   800000  2625.156338
# 49  1000000  3179.137503

# %% [markdown]
# # SAC - D3RL043-D3RL045 - Walker2d

# %%
D3RL043_SAC_RESULTS = "../../dogo_results/d3rlpy/models/sac/Walker2d-v2/2022.08.31-15:46:49/SAC_1443_20220831154653"
D3RL044_SAC_RESULTS = "../../dogo_results/d3rlpy/models/sac/Walker2d-v2/2022.08.31-15:50:29/SAC_1234_20220831155031"
D3RL045_SAC_RESULTS = "../../dogo_results/d3rlpy/models/sac/Walker2d-v2/2022.08.31-15:47:43/SAC_4321_20220831154743"

# %%
d3rl043_sac_rollout_return = pd.read_csv(os.path.join(D3RL043_SAC_RESULTS, SAC_ROLLOUT_RETURN_FILENAME), header=None, names='index step return'.split())
d3rl044_sac_rollout_return = pd.read_csv(os.path.join(D3RL044_SAC_RESULTS, SAC_ROLLOUT_RETURN_FILENAME), header=None, names='index step return'.split())
d3rl045_sac_rollout_return = pd.read_csv(os.path.join(D3RL045_SAC_RESULTS, SAC_ROLLOUT_RETURN_FILENAME), header=None, names='index step return'.split())

# %%
d3rl043_sac_evaluation = pd.read_csv(os.path.join(D3RL043_SAC_RESULTS, SAC_EVALUATION_FILENAME), header=None, names='index step return'.split())
d3rl044_sac_evaluation = pd.read_csv(os.path.join(D3RL044_SAC_RESULTS, SAC_EVALUATION_FILENAME), header=None, names='index step return'.split())
d3rl045_sac_evaluation = pd.read_csv(os.path.join(D3RL045_SAC_RESULTS, SAC_EVALUATION_FILENAME), header=None, names='index step return'.split())

# %%
fig, ax = plt.subplots(1, 1, figsize=(20,10))
ax.plot(d3rl043_sac_rollout_return['step'], d3rl043_sac_rollout_return['return'], label='D3RL040')
ax.plot(d3rl044_sac_rollout_return['step'], d3rl044_sac_rollout_return['return'], label='D3RL041')
ax.plot(d3rl045_sac_rollout_return['step'], d3rl045_sac_rollout_return['return'], label='D3RL042')
ax.set_xlabel('Steps')
ax.set_ylabel('Return')
# ax.set_xlim(0,100000)
# ax.set_ylim(-500,6000)
ax.legend()
pass

# %%
d3rl043_sac_rollout_return[d3rl043_sac_rollout_return['step'].isin([100000, 200000, 500000, 1000000, 2000000])][['step', 'return']]
# Out:
#        step       return
# 4    100000   368.613523
# 9    200000  1586.564480
# 24   500000  3900.472407
# 49  1000000  4312.481972
# 99  2000000  5429.887854
